# %%
import pandas as pd

# %%
df = pd.read_csv("C:\\Users\\ramya\\Downloads\\happy_sunny.csv")
df
# Out:
#                                Country      Continent     Year   RANK  \
# 0                          Afghanistan           Asia  3175.10  146.0
# 1                              Albania         Europe  2544.00   90.0
# 2                              Algeria         Africa  3266.50   96.0
# 3                            Argentina  South America  2220.30   57.0
# 4                              Armenia           Asia  2474.00   82.0
# ..                                 ...            ...      ...    ...
# 101                         Uzbekistan           Asia  2823.90   53.0
# 102  Venezuela, Bolivarian Republic of  South America  2895.30  108.0
# 103                           Viet Nam           Asia  2123.50   77.0
# 104                             Zambia         Africa  2965.47  137.0
# 105                           Zimbabwe         Africa  3065.40  144.0
#
#      Happiness score  Dystopia (1.83) + residual  \
# 0              2.404                       1.263
# ...

# %%
df.dtypes
# Out:
# Country                                        object
# Continent                                      object
# Year                                          float64
# RANK                                          float64
# Happiness score                               float64
# Dystopia (1.83) + residual                    float64
# Explained by: GDP per capita                  float64
# Explained by: Social support                  float64
# Explained by: Healthy life expectancy         float64
# Explained by: Freedom to make life choices    float64
# Explained by: Generosity                      float64
# Explained by: Perceptions of corruption       float64
# dtype: object
